# %% [markdown]
# The idea and the code from http://codereview.stackexchange.com/a/37059/99441 and https://joernhees.de/blog/2015/08/26/scipy-hierarchical-clustering-and-dendrogram-tutorial/

# %%
import sqlite3

from scipy.cluster.hierarchy import dendrogram, linkage, cophenet
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import fcluster
import numpy as np
from jellyfish import jaro_distance
from matplotlib import pyplot as plt

from main import get_primitive_authors

# %%
# %matplotlib inline
np.set_printoptions(precision=5, suppress=True)  # suppress scientific float notation

# %%
db_name = '../Database/src/main/resources/test.db'
conn = sqlite3.connect(db_name)
conn.row_factory = sqlite3.Row
cursor = conn.cursor()
primitive_authors = get_primitive_authors(cursor)
primitive_authors_sname = [a['surname'] for a in primitive_authors]
primitive_authors_id = [a['_id'] for a in primitive_authors]

# %%
def d(coord):
    i, j = coord
    return 1 - jaro_distance(primitive_authors[i]['surname'], primitive_authors[j]['surname'])

# %%
triu_distances = np.apply_along_axis(d, 0, np.triu_indices(len(primitive_authors), 1))
Z = linkage(triu_distances)

# %%
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.show()

# %%
plt.title('Hierarchical Clustering Dendrogram (truncated)')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=12,  # show only the last p merged clusters
    show_leaf_counts=False,  # otherwise numbers in brackets are counts
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.show()

# %%
plt.title('Hierarchical Clustering Dendrogram (truncated)')
plt.xlabel('sample index or (cluster size)')
plt.ylabel('distance')
dendrogram(
    Z,
    truncate_mode='lastp',  # show only the last p merged clusters
    p=12,  # show only the last p merged clusters
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.show()

# %%
def fancy_dendrogram(*args, **kwargs):
    max_d = kwargs.pop('max_d', None)
    if max_d and 'color_threshold' not in kwargs:
        kwargs['color_threshold'] = max_d
    annotate_above = kwargs.pop('annotate_above', 0)

    ddata = dendrogram(*args, **kwargs)

    if not kwargs.get('no_plot', False):
        plt.title('Hierarchical Clustering Dendrogram (truncated)')
        plt.xlabel('sample index or (cluster size)')
        plt.ylabel('distance')
        for i, d, c in zip(ddata['icoord'], ddata['dcoord'], ddata['color_list']):
            x = 0.5 * sum(i[1:3])
            y = d[1]
            if y > annotate_above:
                plt.plot(x, y, 'o', c=c)
                plt.annotate("%.3g" % y, (x, y), xytext=(0, -5),
                             textcoords='offset points',
                             va='top', ha='center')
        if max_d:
            plt.axhline(y=max_d, c='k')
    return ddata

# %%
fancy_dendrogram(
    Z,
    truncate_mode='lastp',
    p=12,
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,
    annotate_above=10,  # useful in small plots so annotations don't overlap
)
plt.show()

# %%
max_d = 0.1

# %%
fancy_dendrogram(
    Z,
    truncate_mode='lastp',
    p=12,
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,
    annotate_above=10,
    max_d=max_d,  # plot a horizontal cut-off line
)
plt.show()

# %%
max_d = 0.1
clusters = fcluster(Z, max_d, criterion='distance')

# %%
primitive_authors = np.array(primitive_authors)
max_index = max(clusters)
clustered = [primitive_authors[np.where(clusters == i)] for i in xrange(1, max_index + 1)]
for c in clustered:
    print c, '\n\n'
# Out:
# [[29 u'Zhou W' u'Zhou, Wei' 9 None u'Zhou, Wei' 0 None]
#  [37 u'Zhou W' u'Zhou, Wei' 12 None u'Zhou, Wei' 0 None]
#  [53 u'Zhou W' u'Zhou, Wei' 16 None u'Zhou, Wei' 0 None]]
#
#
# [[3 u'Rizavi HS' u'Rizavi, Hooriyah S' 3 None u'Rizavi, Hooriyah S' 0 None]]
#
#
# [[6 u'Dwivedi Y' u'Dwivedi, Yogesh' 3 None u'Dwivedi, Yogesh' 0 None]]
#
#
# [[22 u'Martone ME' u'Martone, Maryann E' 7 None u'Martone, Maryann E' 0
#   None]]
#
#
# [[47 u'Larson J' u'Larson, John' 14 None u'Larson, John' 0 None]]
#
#
# [[2 u'Lugli G' u'Lugli, Giovanni' 3 None u'Lugli, Giovanni' 0 None]
#  [40 u'Lugli G' u'Lugli, Giovanni' 13 None u'Lugli, Giovanni' 0 None]
#  [45 u'Lugli G' u'Lugli, Giovanni' 14 None u'Lugli, Giovanni' 0 None]]
#
#
# [[5 u'Turecki G' u'Turecki, Gustavo' 3 None u'Turecki, Gustavo' 0 None]]
#
#
# [[1 u'Smalheiser NR' u'Smalheiser, Neil R' 3 None u'Smalheiser, Neil R' 0
#   None]
#  [10 u'Smalheiser NR' u'Smalheiser, Neil R' 4 None u'Smalheiser, Neil R' 0
#   None]
#  [11 u'Smalheiser NR' u'Smalheiser, Neil R' 5 None u'Smalheiser, Neil R' 0
#   None]
#  [13 u'Smalheiser NR' u'Smalheiser, Neil R' 6 None u'Smalheiser, Neil R' 0
#   None]
#  [15 u'Smalheiser NR' u'Smalheiser, Neil R' 7 None u'Smalheiser, Neil R' 0
#   None]
#  [27 u'Smalheiser NR' u'Smalheiser, Neil R' 8 None u'Smalheiser, Neil R' 0
#   None]
#  [31 u'Smalheiser NR' u'Smalheiser, Neil R' 9 None u'Smalheiser, Neil R' 0
#   None]
#  [32 u'Smalheiser NR' u'Smalheiser, Neil R' 10 None u'Smalheiser, Neil R' 0
#   None]
#  [35 u'Smalheiser NR' u'Smalheiser, Neil R' 11 None u'Smalheiser, Neil R' 0
#   None]
#  [36 u'Smalheiser NR' u'Smalheiser, Neil R' 12 None u'Smalheiser, Neil R' 0
#   None]
#  [39 u'Smalheiser NR' u'Smalheiser, Neil R' 13 None u'Smalheiser, Neil R' 0
#   None]
#  [48 u'Smalheiser NR' u'Smalheiser, Neil R' 14 None u'Smalheiser, Neil R' 0
#   None]
#  [50 u'Smalheiser NR' u'Smalheiser, Neil R' 15 None u'Smalheiser, Neil R' 0
#   None]
#  [51 u'Smalheiser NR' u'Smalheiser, Neil R' 16 None u'Smalheiser, Neil R' 0
#   None]]
#
#
# [[24 u'Price DL' u'Price, Diana L' 7 None u'Price, Diana L' 0 None]]
#
#
# [[42 u'Mise N' u'Mise, Nathan' 13 None u'Mise, Nathan' 0 None]]
#
#
# [[19 u'Gabriel M' u'Gabriel, Michael' 7 None u'Gabriel, Michael' 0 None]]
#
#
# [[21 u'Kashef A' u'Kashef, Alireza' 7 None u'Kashef, Alireza' 0 None]]
#
#
# [[8 u'Weeber M' u'Weeber, Marc' 4 None u'Weeber, Marc' 0 None]]
#
#
# [[18 u'Burhans LB' u'Burhans, Lauren B' 7 None u'Burhans, Lauren B' 0 None]]
#
#
# [[23 u'Perkins GA' u'Perkins, Guy A' 7 None u'Perkins, Guy A' 0 None]]
#
#
# [[9 u'Swanson DR' u'Swanson, Don R' 4 None u'Swanson, Don R' 0 None]]
#
#
# [[26 u'West R' u'West, Ruth' 7 None u'West, Ruth' 0 None]]
#
#
# [[44 u'Abe K' u'Abe, Kuniya' 13 None u'Abe, Kuniya' 0 None]]
#
#
# [[17 u'Bischoff-Grethe A' u'Bischoff-Grethe, Amanda' 7 None
#   u'Bischoff-Grethe, Amanda' 0 None]]
#
#
# [[20 u'Homayouni R' u'Homayouni, Ramin' 7 None u'Homayouni, Ramin' 0 None]]
#
#
# [[4 u'Torvik VI' u'Torvik, Vetle I' 3 None u'Torvik, Vetle I' 0 None]
#  [7 u'Torvik VI' u'Torvik, Vetle I' 4 None u'Torvik, Vetle I' 0 None]
#  [12 u'Torvik VI' u'Torvik, Vetle I' 5 None u'Torvik, Vetle I' 0 None]
#  [14 u'Torvik VI' u'Torvik, Vetle I' 6 None u'Torvik, Vetle I' 0 None]
#  [16 u'Torvik VI' u'Torvik, Vetle I' 7 None u'Torvik, Vetle I' 0 None]
#  [28 u'Torvik VI' u'Torvik, Vetle I' 8 None u'Torvik, Vetle I' 0 None]
#  [30 u'Torvik VI' u'Torvik, Vetle I' 9 None u'Torvik, Vetle I' 0 None]
#  [33 u'Torvik VI' u'Torvik, Vetle I' 10 None u'Torvik, Vetle I' 0 None]
#  [34 u'Torvik VI' u'Torvik, Vetle I' 11 None u'Torvik, Vetle I' 0 None]
#  [38 u'Torvik VI' u'Torvik, Vetle I' 12 None u'Torvik, Vetle I' 0 None]
#  [41 u'Torvik VI' u'Torvik, Vetle I' 13 None u'Torvik, Vetle I' 0 None]
#  [46 u'Torvik VI' u'Torvik, Vetle I' 14 None u'Torvik, Vetle I' 0 None]
#  [49 u'Torvik VI' u'Torvik, Vetle I' 15 None u'Torvik, Vetle I' 0 None]
#  [52 u'Torvik VI' u'Torvik, Vetle I' 16 None u'Torvik, Vetle I' 0 None]]
#
#
# [[25 u'Talk AC' u'Talk, Andrew C' 7 None u'Talk, Andrew C' 0 None]]
#
#
# [[43 u'Ikeda R' u'Ikeda, Rieko' 13 None u'Ikeda, Rieko' 0 None]]

# %%
# Disturb some data
primitive_authors = [dict(row) for row in get_primitive_authors(cursor)]
primitive_authors[3]['surname'] = u'Tarvik, Vetle I'
primitive_authors[6]['surname'] = u'Tarviik, Vetle I'

# %%
triu_distances = np.apply_along_axis(d, 0, np.triu_indices(len(primitive_authors), 1))
Z = linkage(triu_distances)

# %%
c, coph_dists = cophenet(Z, triu_distances)
c
# Out:
# 0.95793184578925206

# %%
fancy_dendrogram(
    Z,
    truncate_mode='lastp',
    p=12,
    leaf_rotation=90.,
    leaf_font_size=12.,
    show_contracted=True,
    annotate_above=10,
    max_d=max_d,  # plot a horizontal cut-off line
)
plt.show()

# %%
max_d = 0.1
clusters = fcluster(Z, max_d, criterion='distance')
np_primitive_authors = np.array(primitive_authors)
max_index = max(clusters)
clustered = [np_primitive_authors[np.where(clusters == i)] for i in xrange(1, max_index + 1)]
for c in clustered:
    print c, '\n\n'
# Out:
# [ {'surname': u'Zhou, Wei', 'name': u'Zhou W', 'encoding': u'Zhou, Wei', 'inference_id': 0, 'source': None, 'author': None, 'article': 9, '_id': 29}
#  {'surname': u'Zhou, Wei', 'name': u'Zhou W', 'encoding': u'Zhou, Wei', 'inference_id': 0, 'source': None, 'author': None, 'article': 12, '_id': 37}
#  {'surname': u'Zhou, Wei', 'name': u'Zhou W', 'encoding': u'Zhou, Wei', 'inference_id': 0, 'source': None, 'author': None, 'article': 16, '_id': 53}]
#
#
# [ {'surname': u'Rizavi, Hooriyah S', 'name': u'Rizavi HS', 'encoding': u'Rizavi, Hooriyah S', 'inference_id': 0, 'source': None, 'author': None, 'article': 3, '_id': 3}]
#
#
# [ {'surname': u'Dwivedi, Yogesh', 'name': u'Dwivedi Y', 'encoding': u'Dwivedi, Yogesh', 'inference_id': 0, 'source': None, 'author': None, 'article': 3, '_id': 6}]
#
#
# [ {'surname': u'Martone, Maryann E', 'name': u'Martone ME', 'encoding': u'Martone, Maryann E', 'inference_id': 0, 'source': None, 'author': None, 'article': 7, '_id': 22}]
#
#
# [ {'surname': u'Larson, John', 'name': u'Larson J', 'encoding': u'Larson, John', 'inference_id': 0, 'source': None, 'author': None, 'article': 14, '_id': 47}]
#
#
# [ {'surname': u'Lugli, Giovanni', 'name': u'Lugli G', 'encoding': u'Lugli, Giovanni', 'inference_id': 0, 'source': None, 'author': None, 'article': 3, '_id': 2}
#  {'surname': u'Lugli, Giovanni', 'name': u'Lugli G', 'encoding': u'Lugli, Giovanni', 'inference_id': 0, 'source': None, 'author': None, 'article': 13, '_id': 40}
#  {'surname': u'Lugli, Giovanni', 'name': u'Lugli G', 'encoding': u'Lugli, Giovanni', 'inference_id': 0, 'source': None, 'author': None, 'article': 14, '_id': 45}]
#
#
# [ {'surname': u'Turecki, Gustavo', 'name': u'Turecki G', 'encoding': u'Turecki, Gustavo', 'inference_id': 0, 'source': None, 'author': None, 'article': 3, '_id': 5}]
#
#
# [ {'surname': u'Swanson, Don R', 'name': u'Swanson DR', 'encoding': u'Swanson, Don R', 'inference_id': 0, 'source': None, 'author': None, 'article': 4, '_id': 9}]
#
#
# [ {'surname': u'Perkins, Guy A', 'name': u'Perkins GA', 'encoding': u'Perkins, Guy A', 'inference_id': 0, 'source': None, 'author': None, 'article': 7, '_id': 23}]
#
#
# [ {'surname': u'Burhans, Lauren B', 'name': u'Burhans LB', 'encoding': u'Burhans, Lauren B', 'inference_id': 0, 'source': None, 'author': None, 'article': 7, '_id': 18}]
#
#
# [ {'surname': u'Tarvik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 3, '_id': 4}
#  {'surname': u'Tarviik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 4, '_id': 7}
#  {'surname': u'Torvik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 5, '_id': 12}
#  {'surname': u'Torvik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 6, '_id': 14}
#  {'surname': u'Torvik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 7, '_id': 16}
#  {'surname': u'Torvik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 8, '_id': 28}
#  {'surname': u'Torvik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 9, '_id': 30}
#  {'surname': u'Torvik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 10, '_id': 33}
#  {'surname': u'Torvik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 11, '_id': 34}
#  {'surname': u'Torvik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 12, '_id': 38}
#  {'surname': u'Torvik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 13, '_id': 41}
#  {'surname': u'Torvik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 14, '_id': 46}
#  {'surname': u'Torvik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 15, '_id': 49}
#  {'surname': u'Torvik, Vetle I', 'name': u'Torvik VI', 'encoding': u'Torvik, Vetle I', 'inference_id': 0, 'source': None, 'author': None, 'article': 16, '_id': 52}]
#
#
# [ {'surname': u'Talk, Andrew C', 'name': u'Talk AC', 'encoding': u'Talk, Andrew C', 'inference_id': 0, 'source': None, 'author': None, 'article': 7, '_id': 25}]
#
#
# [ {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 3, '_id': 1}
#  {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 4, '_id': 10}
#  {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 5, '_id': 11}
#  {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 6, '_id': 13}
#  {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 7, '_id': 15}
#  {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 8, '_id': 27}
#  {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 9, '_id': 31}
#  {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 10, '_id': 32}
#  {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 11, '_id': 35}
#  {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 12, '_id': 36}
#  {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 13, '_id': 39}
#  {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 14, '_id': 48}
#  {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 15, '_id': 50}
#  {'surname': u'Smalheiser, Neil R', 'name': u'Smalheiser NR', 'encoding': u'Smalheiser, Neil R', 'inference_id': 0, 'source': None, 'author': None, 'article': 16, '_id': 51}]
#
#
# [ {'surname': u'Price, Diana L', 'name': u'Price DL', 'encoding': u'Price, Diana L', 'inference_id': 0, 'source': None, 'author': None, 'article': 7, '_id': 24}]
#
#
# [ {'surname': u'Mise, Nathan', 'name': u'Mise N', 'encoding': u'Mise, Nathan', 'inference_id': 0, 'source': None, 'author': None, 'article': 13, '_id': 42}]
#
#
# [ {'surname': u'Gabriel, Michael', 'name': u'Gabriel M', 'encoding': u'Gabriel, Michael', 'inference_id': 0, 'source': None, 'author': None, 'article': 7, '_id': 19}]
#
#
# [ {'surname': u'Kashef, Alireza', 'name': u'Kashef A', 'encoding': u'Kashef, Alireza', 'inference_id': 0, 'source': None, 'author': None, 'article': 7, '_id': 21}]
#
#
# [ {'surname': u'Weeber, Marc', 'name': u'Weeber M', 'encoding': u'Weeber, Marc', 'inference_id': 0, 'source': None, 'author': None, 'article': 4, '_id': 8}]
#
#
# [ {'surname': u'West, Ruth', 'name': u'West R', 'encoding': u'West, Ruth', 'inference_id': 0, 'source': None, 'author': None, 'article': 7, '_id': 26}]
#
#
# [ {'surname': u'Abe, Kuniya', 'name': u'Abe K', 'encoding': u'Abe, Kuniya', 'inference_id': 0, 'source': None, 'author': None, 'article': 13, '_id': 44}]
#
#
# [ {'surname': u'Bischoff-Grethe, Amanda', 'name': u'Bischoff-Grethe A', 'encoding': u'Bischoff-Grethe, Amanda', 'inference_id': 0, 'source': None, 'author': None, 'article': 7, '_id': 17}]
#
#
# [ {'surname': u'Homayouni, Ramin', 'name': u'Homayouni R', 'encoding': u'Homayouni, Ramin', 'inference_id': 0, 'source': None, 'author': None, 'article': 7, '_id': 20}]
#
#
# [ {'surname': u'Ikeda, Rieko', 'name': u'Ikeda R', 'encoding': u'Ikeda, Rieko', 'inference_id': 0, 'source': None, 'author': None, 'article': 13, '_id': 43}]
